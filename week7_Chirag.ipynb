# %% [markdown]
# # RAG Document Question Answering (Latest LangChain)

# %%
# %pip install -q -U langchain langchain-community langchain-text-splitters langchain-huggingface sentence-transformers faiss-cpu pypdf transformers torch
# Out:
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Dell\AppData\Roaming\Python\Python311\site-packages\~.kenizers'.
#   You can safely remove it manually.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Program Files\Python311\python.exe
# 3.11.5 (tags/v3.11.5:cce6ba9, Aug 24 2023, 14:38:34) [MSC v.1936 64 bit (AMD64)]

# %%
# %pip install --upgrade pip
# %pip install torch --no-deps
# %pip install transformers==4.52.4
# %pip install sentence-transformers
# %pip install langchain langchain-community langchain-huggingface langchain-text-splitters faiss-cpu pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# ...
#   Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# ...
# Using cached transformers-4.52.4-py3-none-any.whl (10.5 MB)
# Using cached tokenizers-0.21.4-cp39-abi3-win_amd64.whl (2.5 MB)
# ...
#
#   Attempting uninstall: tokenizers
#
#     Found existing installation: tokenizers 0.22.2
#
#     Uninstalling tokenizers-0.22.2:
#
#       Successfully uninstalled tokenizers-0.22.2
#
#    ---------------------------------------- 0/2 [tokenizers]
#    ---------------------------------------- 0/2 [tokenizers]
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from transformers import pipeline

# %%
pdf_path = r"C:\Users\Dell\Downloads\Deep Learning Roadmap (1).pdf"
loader=PyPDFLoader(pdf_path)
documents=loader.load()
print(len(documents))
# Out:
# 25

# %%
chunk_size=500
chunk_overlap=100
splitter=RecursiveCharacterTextSplitter(chunk_size=chunk_size,chunk_overlap=chunk_overlap)
chunks=splitter.split_documents(documents)
embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
db=FAISS.from_documents(chunks,embeddings)
db.save_local('vector_db')

# %%
generator=pipeline('text2text-generation',model='google/flan-t5-base')
# Out:
# Device set to use cpu

# %%
db=FAISS.load_local('vector_db',embeddings,allow_dangerous_deserialization=True)
q=input('Question: ')
docs=db.similarity_search(q,k=3)
ctx='\n'.join(d.page_content for d in docs)
prompt=f'Context:\n{ctx}\n\nQuestion:{q}\nAnswer:'
print(generator(prompt,max_length=200)[0]['generated_text'])
# Out:
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ResNet Solution Skip Connections. Normal CNN: ResNet: Input directly added later. Why Helps? Gradient travels easily. Training Accuracy Decreases Degradation Problem Input  Layer  Layer  Output Input  Layer  Layer  + |______| Gradient Learning Rate Optimizer Epoch Batch Iteration Loss Function MSE Cross Entropy Overfitting Underfitting Dropout CNN Filter Kernel Convolution Feature Map Stride Padding Pooling Flatten Dense Layer LeNet AlexNet VGG16 ResNet Residual Block Skip Connection Transfer Learning Feature Extraction Fine Tuning ImageNet Data Augmentation Batch Normalization Dense Layer

# %%
print({'chunk_size':chunk_size,'chunk_overlap':chunk_overlap,'chunks':len(chunks),'embedding_dimension':384,'vector_store':'FAISS','top_k':3})
# Out:
# {'chunk_size': 500, 'chunk_overlap': 100, 'chunks': 26, 'embedding_dimension': 384, 'vector_store': 'FAISS', 'top_k': 3}
