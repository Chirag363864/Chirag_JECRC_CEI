# %% [markdown]
# # Customer Intelligence System
#
# This notebook implements clustering and ensemble learning techniques on the dataset using K-Means, DBSCAN, Random Forest, and XGBoost.

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn xgboost -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv('country-data.csv')
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %%
print('Rows:',df.shape[0])
print('Columns:',df.shape[1])
# Out:
# Rows: 167
# Columns: 10

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    str
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), str(1)
# memory usage: 14.5 KB

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='str')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.drop('country',axis=1).corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df.hist(figsize=(15,12),bins=20)
plt.tight_layout()
plt.show()

# %%
for col in df.columns[1:]:
    plt.figure(figsize=(8,3))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
X = df.drop('country',axis=1)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled.shape
# Out:
# (167, 9)

# %%
wcss = []
for i in range(1,11):
    model = KMeans(n_clusters=i,random_state=42,n_init=10)
    model.fit(X_scaled)
    wcss.append(model.inertia_)

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11),wcss,marker='o')
plt.xlabel('Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters=3,random_state=42,n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)
df[['country','Cluster']].head()
# Out:
#                country  Cluster
# 0          Afghanistan        1
# 1              Albania        2
# 2              Algeria        2
# 3               Angola        1
# 4  Antigua and Barbuda        2

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 2    84
# 1    47
# 0    36
# Name: count, dtype: int64

# %%
dbscan = DBSCAN(eps=1.5,min_samples=5)
df['DBSCAN_Cluster'] = dbscan.fit_predict(X_scaled)
df['DBSCAN_Cluster'].value_counts()
# Out:
# DBSCAN_Cluster
#  0    137
# -1     30
# Name: count, dtype: int64

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_scaled)
pca_df = pd.DataFrame(pca_data,columns=['PC1','PC2'])

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=pca_df['PC1'],y=pca_df['PC2'],hue=df['Cluster'],palette='Set1')
plt.title('K-Means Clusters')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=pca_df['PC1'],y=pca_df['PC2'],hue=df['DBSCAN_Cluster'],palette='Set2')
plt.title('DBSCAN Clusters')
plt.show()

# %%
cluster_profile = df.groupby('Cluster').mean(numeric_only=True)
cluster_profile
# Out:
#          child_mort    exports    health    imports        income  inflation  \
# Cluster
# 0          5.000000  58.738889  8.807778  51.491667  45672.222222   2.671250
# 1         92.961702  29.151277  6.388511  42.323404   3942.404255  12.019681
# 2         21.927381  40.243917  6.200952  47.473404  12305.595238   7.600905
#
#          life_expec  total_fer          gdpp  DBSCAN_Cluster
# Cluster
# 0         80.127778   1.752778  42494.444444       -0.250000
# 1         59.187234   5.008085   1922.382979       -0.340426
# 2         72.814286   2.307500   6486.452381       -0.059524

# %%
df['Segment'] = df['Cluster']

X_cls = df.drop(['country','Cluster','DBSCAN_Cluster','Segment'],axis=1)
y_cls = df['Segment']

X_train,X_test,y_train,y_test = train_test_split(
    X_cls,y_cls,test_size=0.2,random_state=42
)

# %%
rf = RandomForestClassifier(n_estimators=200,random_state=42)
rf.fit(X_train,y_train)
rf_pred = rf.predict(X_test)

print('Accuracy:',accuracy_score(y_test,rf_pred))
print(classification_report(y_test,rf_pred))
# Out:
# Accuracy: 0.9705882352941176
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.86      1.00      0.92         6
#            2       1.00      0.95      0.97        20
#
#     accuracy                           0.97        34
#    macro avg       0.95      0.98      0.97        34
# weighted avg       0.97      0.97      0.97        34

# %%
cm_rf = confusion_matrix(y_test, rf_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
importance = pd.DataFrame({
    'Feature':X_cls.columns,
    'Importance':rf.feature_importances_
}).sort_values(by='Importance',ascending=False)

importance
# Out:
#       Feature  Importance
# 0  child_mort    0.279315
# 8        gdpp    0.196765
# 4      income    0.155490
# 6  life_expec    0.151215
# 7   total_fer    0.149904
# 2      health    0.032411
# 5   inflation    0.014174
# 1     exports    0.013982
# 3     imports    0.006743

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=importance,x='Importance',y='Feature')
plt.title('Feature Importance')
plt.show()

# %%
xgb = XGBClassifier(
    n_estimators=200,
    random_state=42,
    eval_metric='mlogloss'
)

xgb.fit(X_train,y_train)
xgb_pred = xgb.predict(X_test)

print('Accuracy:',accuracy_score(y_test,xgb_pred))
print(classification_report(y_test,xgb_pred))
# Out:
# Accuracy: 0.9705882352941176
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         8
#            1       0.86      1.00      0.92         6
#            2       1.00      0.95      0.97        20
#
#     accuracy                           0.97        34
#    macro avg       0.95      0.98      0.97        34
# weighted avg       0.97      0.97      0.97        34

# %%
cm_xgb = confusion_matrix(y_test, xgb_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm_xgb, annot=True, fmt='d', cmap='Greens')
plt.title('XGBoost Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
rf_acc = accuracy_score(y_test,rf_pred)
xgb_acc = accuracy_score(y_test,xgb_pred)

comparison = pd.DataFrame({
    'Model':['Random Forest','XGBoost'],
    'Accuracy':[rf_acc,xgb_acc]
})

comparison
# Out:
#            Model  Accuracy
# 0  Random Forest  0.970588
# 1        XGBoost  0.970588

# %% [markdown]
# ## Conclusion
#
# The workflow successfully identified distinct segments using clustering techniques and leveraged ensemble learning models for predictive analysis. Income, GDP per capita, life expectancy, and child mortality emerged as influential variables in segment formation. The resulting segmentation can support strategic decision-making and targeted policy planning.
